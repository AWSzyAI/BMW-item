# %%
import pandas as pd
df = pd.read_csv("./output/df_filtered.csv")
df
# Out:
#       Unnamed: 0  extern_id  linked_items itemcreationdate  \
# 0              0      51255         51255        7/14/2025
# 1              1      51255         51255        7/14/2025
# 2              2      51830         51830         8/5/2025
# 3              3      52118         52118        8/15/2025
# 4              4      52077         52077        8/13/2025
# ...          ...        ...           ...              ...
# 2067        2067      51881         51881         8/6/2025
# 2068        2068      51109         46365         7/8/2025
# 2069        2069      51109         51109         7/8/2025
# 2070        2070      52011         52011        8/11/2025
# 2071        2071      51221         51221        7/11/2025
#
#                                              item_title  case_id  \
# 0     EQF CN IDC23 Display freeze, screen stuck. PU ...  4270191
# 1     EQF CN IDC23 Display freeze, screen stuck. PU ...  4230193
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2072 entries, 0 to 2071
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        2072 non-null   int64
#  1   extern_id         2072 non-null   int64
#  2   linked_items      2072 non-null   int64
#  3   itemcreationdate  2072 non-null   object
#  4   item_title        2072 non-null   object
#  5   case_id           2072 non-null   int64
#  6   case_title        2072 non-null   object
#  7   performed_work    2072 non-null   object
# dtypes: int64(4), object(4)
# memory usage: 129.6+ KB
